# %% [markdown]
# <a href="https://colab.research.google.com/github/rushibyna132/CodeAlpha_Stock_Portfolio_Tracker/blob/main/CodeAlpha_Stock_Portfolio_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Stock Portfolio Tracker

# Hardcoded stock prices
stock_prices = {
    "AAPL": 180,
    "TSLA": 250,
    "GOOGL": 150,
    "MSFT": 420
}

total_investment = 0
portfolio = []

print("📊 Stock Portfolio Tracker")

while True:
    stock_name = input("\nEnter stock name (or type 'done' to finish): ").upper()

    if stock_name == "DONE":
        break

    if stock_name not in stock_prices:
        print("Stock not found!")
        continue

    quantity = int(input("Enter quantity: "))

    price = stock_prices[stock_name]
    investment = price * quantity

    total_investment += investment

    portfolio.append(
        f"{stock_name} - Quantity: {quantity}, Price: {price}, Investment: {investment}"
    )

    print("Investment:", investment)

print("\n----- Portfolio Summary -----")

for item in portfolio:
    print(item)

print("\nTotal investment:", total_investment)

# Save the portfolio to a text file
with open("stock_portfolio.txt", "w") as file:
    file.write("Stock Portfolio Tracker\n")
    file.write("-----------------------\n")

    for item in portfolio:
        file.write(item + "\n")

    file.write(f"\nTotal investment: {total_investment}")

print("\nPortfolio saved successfully as stock_portfolio.txt")
# Out:
# 📊 Stock Portfolio Tracker
#
# Enter stock name (or type 'done' to finish): Aapl
# Enter quantity: 5
# Investment: 900
#
# Enter stock name (or type 'done' to finish): Msft
# Enter quantity: 16
# Investment: 6720
#
# Enter stock name (or type 'done' to finish): Tsla
# Enter quantity: 2
# Investment: 500
#
# Enter stock name (or type 'done' to finish): Svc
# Stock not found!
#
# Enter stock name (or type 'done' to finish): Hmg
# Stock not found!
#
# Enter stock name (or type 'done' to finish): Done
#
# ----- Portfolio Summary -----
# AAPL - Quantity: 5, Price: 180, Investment: 900
# MSFT - Quantity: 16, Price: 420, Investment: 6720
# TSLA - Quantity: 2, Price: 250, Investment: 500
#
# Total investment: 8120
#
# Portfolio saved successfully as stock_portfolio.txt
